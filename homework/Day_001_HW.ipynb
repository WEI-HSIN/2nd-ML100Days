# %% [markdown]
# 作業1：請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：New York City Taxi Trip Duration
#
# 1. 你選的這組資料為何重要：有趣且貼近生活
#
# 2. 資料從何而來：NYC Taxi and Limousine Commission (TLC)
#
# 3. 蒐集而來的資料型態為何：結構化資料，包含pickup time, geo-coordinates, number of passengers等變數。
#
# 4. 這組資料想解決的問題如何評估：迴歸RMSLE
#
#
#
# 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)：業績決定於載客次數與車資，車資與顧客目的地遠近有關，相較之下，了解影響載客次數的因素，應較容易進行調整，進而提升業績。
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)：除了顧客基本資料，性別、年齡、職業等，還需要各項行為資訊，如搭乘時間、地點、目的地、是否有固定往返需求、對於搭乘滿意度評分、是否願意再次搭乘、希望額外的加值服務與建議等等。搭乘的地理資訊可藉由司機與車輛設備紀錄，顧客資料與滿意程度可藉預約乘車時詢問，或是搭乘後滿意度問券蒐集。
#
# 3. 蒐集而來的資料型態為何：除了問券中的開放性問題為非結構化資料，其他皆為結構化的資料。
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)：迴歸MSE

# %% [markdown]
# 作業3：

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    MAE = sum(abs(y - yp)) / len(y)
    return MAE

def mean_squared_error(y, yp):
    """
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - MSE
    """
    MSE = sum((yp-y)**2) / len(y)
    return MSE

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 276.697
# The Mean absolute error is 13.661
